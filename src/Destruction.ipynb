# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
labels = pd.read_csv('../csv/train_labels.csv')
labels.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
values = pd.read_csv('../csv/train_values.csv')
values.head(10).T
# Out:
#                                              0      1      2       3       4  \
# building_id                             802906  28830  94947  590882  201944
# geo_level_1_id                               6      8     21      22      11
# geo_level_2_id                             487    900    363     418     131
# geo_level_3_id                           12198   2812   8973   10694    1488
# count_floors_pre_eq                          2      2      2       2       3
# age                                         30     10     10      10      30
# area_percentage                              6      8      5       6       8
# height_percentage                            5      7      5       5       9
# land_surface_condition                       t      o      t       t       t
# foundation_type                              r      r      r       r       r
# roof_type                                    n      n      n       n       n
# ...

# %%
id_position = values[["building_id", "position"]]
merge_position_destruction = id_position.merge(labels, on="building_id")
damage_by_position = pd.pivot_table(merge_position_destruction, index='damage_grade', columns='position',\
                                    values='building_id', aggfunc="count")
damage_by_position.plot(kind="pie",\
     figsize= (15, 10),\
     rot=45, \
     autopct = "%.2f%%", \
     colors = ["lightblue", "blue", "purple"], \
     subplots=True)

#cambiar color a color = ["#11bbff", "#2277ff", "#3300ff"]
# Out:
# array([<AxesSubplot:ylabel='j'>, <AxesSubplot:ylabel='o'>,
#        <AxesSubplot:ylabel='s'>, <AxesSubplot:ylabel='t'>], dtype=object)
